# %%
Students = []
courses = []
Marks = []
# number of students
def CountStudents():
    count = int(input("How many students are there in the course ?"))
    return count

#enter Student
def Student():
    print("Enter Student Infor : ")
    id = input(" ID : ")
    name = input(" Name : ")
    DoB = input(" Date of birth : ")
    A = {"id":id,"name":name,"Date of birth":DoB}
    return A
def Students_List(Students):
    for A in Students:
        print(f"id {A['id']},name is {A['name']},Date of birth is {A['Date of birth']} ")
count = CountStudents()
for i in range(0, count):
    A = Student()
    Students += [ A ] 

#number of courses
def CountCourses():
    count = int(input("How many course are there in the semester ?"))
    return count
#enter Course
def Course():
    print("Enter Course Infor : ")
    id = input(" ID : ")
    name = input(" Name of course : ")
    B = {"id":id,"name":name}
    return B
def Courses_List(Courses):
    for B in Courses:
        print(f"id {B['id']},Name of course is {B['name']}")
count=CountCourses()
for i in range(0, count):
    B = Course()
    Courses += [ B ]

#enter mark
def Mark():
     for i in range(len(students)):
        marks.append({course: {}})
        mark = float(input("Enter " + students[i].get("name") + "'s mark:\n"))
        marks[i].update({course: mark})

def Marks_List():
    print("Student marks for this course:\n")
    for i in range(len(students)):
        print(students[i].get("name") + "'s mark:")
        print(marks[i].get(choose_course))
    
    if __name__ == "__main__":
            student_number = CountStudents()
            print(student_number)
            for i in range(0, student_number):
                    ID, name,DoB = Students()
                    students.append({"id": id, "name": name, "BoB": DoB})
           
            course_number = CountCourses()
            for i in range(0, course_number):
                    ID, name = Courses()
                    courses.append({"id": id, "name": name})
  
    choose_course_id=input("Choose course ID: ")
    for i in range(0,courses):
        if courses[i].get("id") == choose_course_id:
            print("Course name: " + courses[i].get("name") + "\n")
            Mark(students, courses[i].get("name"))

print("All Students:")
Students_List(Students)
print("All Courses:")
Courses_List(Courses)
choose_course = input("Select a course name: ")
Marks_List()
# Out:
# How many students are there in the course ?2
# Enter Student Infor :
#  ID : bi10-077
#  Name : hoang huu huy
#  Birthday : 19/6/2001
# Enter Student Infor :
#  ID : pham hoang viet
#  Name : sda
#  Birthday : asd
# How many course are there in the semester ?3
# Enter Course Infor :
#  ID : ict
#  Name : ict
# Enter Course Infor :
#  ID : ass
#  Name : ass
# Enter Course Infor :
#  ID : ads
#  Name : ads
# All Students:
# id bi10-077,name is hoang huu huy,birthday is 19/6/2001
# id pham hoang viet,name is sda,birthday is asd
# All Courses:
# id ict,name is ict
# id ass,name is ass
# id ads,name is ads
